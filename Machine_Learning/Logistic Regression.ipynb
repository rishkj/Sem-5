# %%
import pandas as pd
import numpy as np
from math import pow

class Logistic_Regression(object):
    def __init__(self,learning_rate,no_columns):
        self.lr = learning_rate
        self.no_columns = no_columns
        
        self.b = [0.0 for i in range(no_columns+1)]
        
    def sigmoid(self,val):
        return 1/(1+np.exp(-val))
    
    def sigmoid_derivative(self,val):
        return val * (1.0 - val)
    
    def predict_class(self,row):
        o = self.b[-1]
        for i in range(len(row)):
            o += row[i]*self.b[i]
        
        return self.sigmoid(o)
    
    def log_reg(self,X,y):
        
        total_error = 0
        for i in range(len(X)):
            o = self.predict_class(X[i])
            error = y[i] - o
            total_error += pow(error,2)
            
            for j in range(self.no_columns):
                self.b[j] += error * self.lr * self.sigmoid_derivative(o) * X[i][j]
                
            self.b[-1] += error * self.lr * self.sigmoid_derivative(o)
            
        total_error = total_error * 0.5/len(X)
        print("Error = ","{:5.4f}".format(total_error))
        return total_error
            
    def cal_acc(self,o,y):
        count = 0
        
        for i in range(len(o)):
            if(o[i] == y[i]):
                count += 1
        
        return count/len(o)
    
    def output_to_list(self,o,threshold):
        
        for i in range(len(o)):
            if o[i] > threshold:
                o[i] = 1
                
            else:
                o[i] = 0
        return o
    
    def train(self,epochs,X,y,threshold):
        
        mse = []
        for epoch in range(epochs):
            print("Epoch ", epoch + 1," : ",end=" ")
            mse.append(self.log_reg(X,y))
        
        print("\n")
            
        o = []
        for i in range(len(X)):
            o.append(self.predict_class(X[i]))
            
        o = self.output_to_list(o,threshold)
        
        acc = self.cal_acc(o,y)
        
        return acc, mse
        
        
        
    def test(self,X,y,threshold):
        
        o = []
        for i in range(len(X)):
            o.append(self.predict_class(X[i]))
            
        o = self.output_to_list(o,threshold)
        
        acc = self.cal_acc(o,y)
        
        return acc

# %%
def split_into_kfolds(df,kfolds):
    df_list = []
    
    size = len(df)
    count = int(size/kfolds)

    for i in range(kfolds):
        beg_index = i * count
        end_index = (i+1) * count
        if i == kfolds-1:
            end_index = size

        df_list.append(df[beg_index:end_index])
        
    return df_list

def normalize(x):
    result = x.copy()
    for feature_name in x.columns:
        max_value = x[feature_name].max()
        min_value = x[feature_name].min()
        result[feature_name] = (x[feature_name] - min_value) / (max_value - min_value)
    return result

# %%
# %matplotlib tk

from sklearn.model_selection import train_test_split
from datetime import datetime
import matplotlib.pyplot as plt



startTime = datetime.now()

df = pd.read_csv('ILPD.csv')
df = normalize(df)

col = col = ['Age','Gender','TB','DB','Alkphos','Sgpt','Sgot','TP','ALB','A/G']
col_class = 'Selector'

df = df.sample(frac = 1)


kfolds = 5
threshold = 0.5
learning_rate = 8 * pow(10,-4)
epochs = 200

score_train = []
score_test = []

count_epochs = range(1,epochs+1)
mse = []

df_list = split_into_kfolds(df,kfolds)

LR = Logistic_Regression(learning_rate,len(col))

mse = []

for i in range(kfolds):
    print("Training on cross-validation ",i+1,"\n" + "\n")
    
    df_train = pd.DataFrame()
    
    for j in range(0,i):
        df_train = pd.concat([df_train,df_list[j]], ignore_index=True)
      
    for j in range(i+1,kfolds):
        df_train = pd.concat([df_train,df_list[j]], ignore_index=True)
        
    df_test = df_list[i]
    
    X_train = df_train[col]
    y_train = df_train[col_class]
    
    X_test = df_test[col]
    y_test = df_test[col_class]
    
    X_train, y_train, X_test, y_test = np.array(X_train), np.array(y_train), np.array(X_test), np.array(y_test)
    
    x, mse = LR.train(epochs,X_train,y_train,threshold)
    
    score_train.append(x)
    
    score_test.append(LR.test(X_test,y_test,threshold))


    
plt.plot(count_epochs, mse, color='green', linestyle='solid', linewidth = 2, marker='o', markerfacecolor='blue', markersize=9) 
# setting x and y axis range 
plt.ylim(min(mse),max(mse)) 
plt.xlim(1,epochs) 
  
# naming the x axis 
plt.xlabel('Epoch number') 
# naming the y axis 
plt.ylabel('MSE') 
  
# giving a title to my graph 
plt.title('Logistic Regression') 
  
# function to show the plot 
plt.show() 

    
train ,test = train_test_split(df, test_size = 0.25)

X_test = test[col]
y_test = test[col_class]
X_test, y_test = np.array(X_test), np.array(y_test)

final_score = LR.test(X_test,y_test,threshold)
    


score_train_mean = sum(score_train)/len(score_train)
print("Training accuracy is : ", "{:5.4f}".format(score_train_mean))

score_test_mean = sum(score_test)/len(score_test)
print("Testing accuracy average of all folds is : ", "{:5.4f}".format(score_test_mean))

print("Final testing accuracy is : ","{:5.4f}".format(final_score))


print("\n")
print("Execution time in seconds = ", datetime.now() - startTime)
# Out:
# Training on cross-validation  1
#
#
# Epoch  1  :  Error =  0.1248
# Epoch  2  :  Error =  0.1243
# Epoch  3  :  Error =  0.1239
# Epoch  4  :  Error =  0.1235
# Epoch  5  :  Error =  0.1231
# Epoch  6  :  Error =  0.1227
# Epoch  7  :  Error =  0.1223
# Epoch  8  :  Error =  0.1220
# Epoch  9  :  Error =  0.1216
# Epoch  10  :  Error =  0.1212
# Epoch  11  :  Error =  0.1209
# Epoch  12  :  Error =  0.1206
# Epoch  13  :  Error =  0.1203
# Epoch  14  :  Error =  0.1200
# Epoch  15  :  Error =  0.1197
# Epoch  16  :  Error =  0.1194
# Epoch  17  :  Error =  0.1191
# Epoch  18  :  Error =  0.1188
# Epoch  19  :  Error =  0.1185
# Epoch  20  :  Error =  0.1183
# Epoch  21  :  Error =  0.1180
# Epoch  22  :  Error =  0.1177
# Epoch  23  :  Error =  0.1175
# Epoch  24  :  Error =  0.1173
# Epoch  25  :  Error =  0.1170
# Epoch  26  :  Error =  0.1168
# Epoch  27  :  Error =  0.1166
# Epoch  28  :  Error =  0.1164
# Epoch  29  :  Error =  0.1162
# Epoch  30  :  Error =  0.1159
# Epoch  31  :  Error =  0.1157
# Epoch  32  :  Error =  0.1156
# Epoch  33  :  Error =  0.1154
# Epoch  34  :  Error =  0.1152
# Epoch  35  :  Error =  0.1150
# Epoch  36  :  Error =  0.1148
# Epoch  37  :  Error =  0.1146
# Epoch  38  :  Error =  0.1145
# Epoch  39  :  Error =  0.1143
# Epoch  40  :  Error =  0.1141
# Epoch  41  :  Error =  0.1140
# Epoch  42  :  Error =  0.1138
# Epoch  43  :  Error =  0.1137
# Epoch  125  :  Error =  0.1069
# Epoch  126  :  Error =  0.1068
# Epoch  127  :  Error =  0.1068
# Epoch  128  :  Error =  0.1067
# Epoch  129  :  Error =  0.1067
# Epoch  130  :  Error =  0.1066
# Epoch  131  :  Error =  0.1066
# Epoch  132  :  Error =  0.1065
# Epoch  133  :  Error =  0.1065
# Epoch  134  :  Error =  0.1065
# Epoch  135  :  Error =  0.1064
# Epoch  136  :  Error =  0.1064
# Epoch  137  :  Error =  0.1063
# Epoch  138  :  Error =  0.1063
# Epoch  139  :  Error =  0.1063
# Epoch  140  :  Error =  0.1062
# Epoch  141  :  Error =  0.1062
# Epoch  142  :  Error =  0.1061
# Epoch  143  :  Error =  0.1061
# Epoch  144  :  Error =  0.1061
# Epoch  145  :  Error =  0.1060
# Epoch  146  :  Error =  0.1060
# Epoch  147  :  Error =  0.1059
# Epoch  148  :  Error =  0.1059
# Epoch  149  :  Error =  0.1059
# Epoch  150  :  Error =  0.1058
# Epoch  151  :  Error =  0.1058
# Epoch  152  :  Error =  0.1058
# Epoch  153  :  Error =  0.1057
# Epoch  154  :  Error =  0.1057
# Epoch  155  :  Error =  0.1056
# Epoch  156  :  Error =  0.1056
# Epoch  157  :  Error =  0.1056
# Epoch  158  :  Error =  0.1055
# Epoch  159  :  Error =  0.1055
# Epoch  160  :  Error =  0.1055
# Epoch  161  :  Error =  0.1054
# Epoch  162  :  Error =  0.1054
# Epoch  163  :  Error =  0.1054
# Epoch  164  :  Error =  0.1053
# Epoch  165  :  Error =  0.1053
# Epoch  166  :  Error =  0.1053
# Epoch  167  :  Error =  0.1052
# Epoch  168  :  Error =  0.1052
# Epoch  169  :  Error =  0.1052
# Epoch  170  :  Error =  0.1052
# Epoch  171  :  Error =  0.1051
# Epoch  172  :  Error =  0.1051
# Epoch  173  :  Error =  0.1051
# Epoch  174  :  Error =  0.1050
# Epoch  175  :  Error =  0.1050
# Epoch  176  :  Error =  0.1050
# Epoch  177  :  Error =  0.1049
# Epoch  178  :  Error =  0.1049
# Epoch  179  :  Error =  0.1049
# Epoch  180  :  Error =  0.1049
# Epoch  181  :  Error =  0.1048
# Epoch  182  :  Error =  0.1048
# Epoch  183  :  Error =  0.1048
# Epoch  184  :  Error =  0.1047
# Epoch  185  :  Error =  0.1047
# Epoch  186  :  Error =  0.1047
# Epoch  187  :  Error =  0.1047
# Epoch  188  :  Error =  0.1046
# Epoch  189  :  Error =  0.1046
# Epoch  190  :  Error =  0.1046
# Epoch  191  :  Error =  0.1045
# Epoch  192  :  Error =  0.1045
# Epoch  193  :  Error =  0.1045
# Epoch  194  :  Error =  0.1045
# Epoch  195  :  Error =  0.1044
# Epoch  196  :  Error =  0.1044
# Epoch  197  :  Error =  0.1044
# Epoch  198  :  Error =  0.1044
# Epoch  199  :  Error =  0.1043
# Epoch  200  :  Error =  0.1043
#
#
# Training on cross-validation  2
#
#
# Epoch  1  :  Error =  0.1042
# Epoch  2  :  Error =  0.1042
# Epoch  3  :  Error =  0.1042
# Epoch  85  :  Error =  0.1026
# Epoch  86  :  Error =  0.1026
# Epoch  87  :  Error =  0.1026
# Epoch  88  :  Error =  0.1025
# Epoch  89  :  Error =  0.1025
# Epoch  90  :  Error =  0.1025
# Epoch  91  :  Error =  0.1025
# Epoch  92  :  Error =  0.1025
# Epoch  93  :  Error =  0.1025
# Epoch  94  :  Error =  0.1025
# Epoch  95  :  Error =  0.1024
# Epoch  96  :  Error =  0.1024
# Epoch  97  :  Error =  0.1024
# Epoch  98  :  Error =  0.1024
# Epoch  99  :  Error =  0.1024
# Epoch  100  :  Error =  0.1024
# Epoch  101  :  Error =  0.1024
# Epoch  102  :  Error =  0.1024
# Epoch  103  :  Error =  0.1023
# Epoch  104  :  Error =  0.1023
# Epoch  105  :  Error =  0.1023
# Epoch  106  :  Error =  0.1023
# Epoch  107  :  Error =  0.1023
# Epoch  108  :  Error =  0.1023
# Epoch  109  :  Error =  0.1023
# Epoch  110  :  Error =  0.1022
# Epoch  111  :  Error =  0.1022
# Epoch  112  :  Error =  0.1022
# Epoch  113  :  Error =  0.1022
# Epoch  114  :  Error =  0.1022
# Epoch  115  :  Error =  0.1022
# Epoch  116  :  Error =  0.1022
# Epoch  117  :  Error =  0.1022
# Epoch  118  :  Error =  0.1021
# Epoch  119  :  Error =  0.1021
# Epoch  120  :  Error =  0.1021
# Epoch  121  :  Error =  0.1021
# Epoch  122  :  Error =  0.1021
# Epoch  123  :  Error =  0.1021
# Epoch  124  :  Error =  0.1021
# Epoch  125  :  Error =  0.1021
# Epoch  126  :  Error =  0.1020
# Epoch  127  :  Error =  0.1020
# Epoch  128  :  Error =  0.1020
# Epoch  129  :  Error =  0.1020
# Epoch  130  :  Error =  0.1020
# Epoch  131  :  Error =  0.1020
# Epoch  132  :  Error =  0.1020
# Epoch  133  :  Error =  0.1020
# Epoch  134  :  Error =  0.1019
# Epoch  135  :  Error =  0.1019
# Epoch  136  :  Error =  0.1019
# Epoch  137  :  Error =  0.1019
# Epoch  138  :  Error =  0.1019
# Epoch  139  :  Error =  0.1019
# Epoch  140  :  Error =  0.1019
# Epoch  141  :  Error =  0.1019
# Epoch  142  :  Error =  0.1019
# Epoch  143  :  Error =  0.1018
# Epoch  144  :  Error =  0.1018
# Epoch  145  :  Error =  0.1018
# Epoch  146  :  Error =  0.1018
# Epoch  147  :  Error =  0.1018
# Epoch  148  :  Error =  0.1018
# Epoch  149  :  Error =  0.1018
# Epoch  150  :  Error =  0.1018
# Epoch  151  :  Error =  0.1018
# Epoch  152  :  Error =  0.1017
# Epoch  153  :  Error =  0.1017
# Epoch  154  :  Error =  0.1017
# Epoch  155  :  Error =  0.1017
# Epoch  156  :  Error =  0.1017
# Epoch  157  :  Error =  0.1017
# Epoch  158  :  Error =  0.1017
# Epoch  159  :  Error =  0.1017
# Epoch  160  :  Error =  0.1017
# Epoch  161  :  Error =  0.1016
# Epoch  162  :  Error =  0.1016
# Epoch  163  :  Error =  0.1016
# Epoch  164  :  Error =  0.1016
# Epoch  165  :  Error =  0.1016
# Epoch  166  :  Error =  0.1016
# Epoch  167  :  Error =  0.1016
# Epoch  168  :  Error =  0.1016
# Epoch  169  :  Error =  0.1016
# Epoch  170  :  Error =  0.1016
# Epoch  171  :  Error =  0.1015
# Epoch  172  :  Error =  0.1015
# Epoch  173  :  Error =  0.1015
# Epoch  174  :  Error =  0.1015
# Epoch  175  :  Error =  0.1015
# Epoch  176  :  Error =  0.1015
# Epoch  177  :  Error =  0.1015
# Epoch  178  :  Error =  0.1015
# Epoch  179  :  Error =  0.1015
# Epoch  180  :  Error =  0.1015
# Epoch  181  :  Error =  0.1014
# Epoch  182  :  Error =  0.1014
# Epoch  183  :  Error =  0.1014
# Epoch  184  :  Error =  0.1014
# Epoch  185  :  Error =  0.1014
# Epoch  186  :  Error =  0.1014
# Epoch  187  :  Error =  0.1014
# Epoch  188  :  Error =  0.1014
# Epoch  189  :  Error =  0.1014
# Epoch  190  :  Error =  0.1014
# Epoch  191  :  Error =  0.1014
# Epoch  192  :  Error =  0.1013
# Epoch  193  :  Error =  0.1013
# Epoch  194  :  Error =  0.1013
# Epoch  195  :  Error =  0.1013
# Epoch  196  :  Error =  0.1013
# Epoch  197  :  Error =  0.1013
# Epoch  198  :  Error =  0.1013
# Epoch  199  :  Error =  0.1013
# Epoch  200  :  Error =  0.1013
#
#
# Training on cross-validation  3
#
#
# Epoch  1  :  Error =  0.1008
# Epoch  2  :  Error =  0.1008
# Epoch  3  :  Error =  0.1008
# Epoch  4  :  Error =  0.1008
# Epoch  5  :  Error =  0.1008
# Epoch  6  :  Error =  0.1008
# Epoch  7  :  Error =  0.1008
# Epoch  8  :  Error =  0.1008
# Epoch  9  :  Error =  0.1008
# Epoch  10  :  Error =  0.1007
# Epoch  11  :  Error =  0.1007
# Epoch  12  :  Error =  0.1007
# Epoch  13  :  Error =  0.1007
# Epoch  14  :  Error =  0.1007
# Epoch  15  :  Error =  0.1007
# Epoch  16  :  Error =  0.1007
# Epoch  17  :  Error =  0.1007
# Epoch  18  :  Error =  0.1007
# Epoch  19  :  Error =  0.1007
# Epoch  20  :  Error =  0.1007
# Epoch  21  :  Error =  0.1007
# Epoch  22  :  Error =  0.1007
# Epoch  23  :  Error =  0.1006
# Epoch  24  :  Error =  0.1006
# Epoch  25  :  Error =  0.1006
# Epoch  26  :  Error =  0.1006
# Epoch  27  :  Error =  0.1006
# Epoch  28  :  Error =  0.1006
# Epoch  29  :  Error =  0.1006
# Epoch  30  :  Error =  0.1006
# Epoch  31  :  Error =  0.1006
# Epoch  32  :  Error =  0.1006
# Epoch  33  :  Error =  0.1006
# Epoch  34  :  Error =  0.1006
# Epoch  35  :  Error =  0.1006
# Epoch  36  :  Error =  0.1005
# Epoch  37  :  Error =  0.1005
# Epoch  38  :  Error =  0.1005
# Epoch  39  :  Error =  0.1005
# Epoch  40  :  Error =  0.1005
# Epoch  41  :  Error =  0.1005
# Epoch  42  :  Error =  0.1005
# Epoch  43  :  Error =  0.1005
# Epoch  44  :  Error =  0.1005
# Epoch  45  :  Error =  0.1005
# Epoch  46  :  Error =  0.1005
# Epoch  47  :  Error =  0.1005
# Epoch  48  :  Error =  0.1005
# Epoch  49  :  Error =  0.1004
# Epoch  50  :  Error =  0.1004
# Epoch  51  :  Error =  0.1004
# Epoch  52  :  Error =  0.1004
# Epoch  53  :  Error =  0.1004
# Epoch  54  :  Error =  0.1004
# Epoch  55  :  Error =  0.1004
# Epoch  56  :  Error =  0.1004
# Epoch  57  :  Error =  0.1004
# Epoch  58  :  Error =  0.1004
# Epoch  59  :  Error =  0.1004
# Epoch  60  :  Error =  0.1004
# Epoch  61  :  Error =  0.1004
# Epoch  62  :  Error =  0.1004
# Epoch  63  :  Error =  0.1004
# Epoch  64  :  Error =  0.1003
# Epoch  65  :  Error =  0.1003
# Epoch  66  :  Error =  0.1003
# Epoch  67  :  Error =  0.1003
# Epoch  68  :  Error =  0.1003
# Epoch  69  :  Error =  0.1003
# Epoch  70  :  Error =  0.1003
# Epoch  71  :  Error =  0.1003
# Epoch  72  :  Error =  0.1003
# Epoch  73  :  Error =  0.1003
# Epoch  74  :  Error =  0.1003
# Epoch  75  :  Error =  0.1003
# Epoch  76  :  Error =  0.1003
# Epoch  77  :  Error =  0.1003
# Epoch  78  :  Error =  0.1003
# Epoch  79  :  Error =  0.1002
# Epoch  80  :  Error =  0.1002
# Epoch  81  :  Error =  0.1002
# Epoch  82  :  Error =  0.1002
# Epoch  83  :  Error =  0.1002
# Epoch  84  :  Error =  0.1002
# Epoch  85  :  Error =  0.1002
# Epoch  86  :  Error =  0.1002
# Epoch  87  :  Error =  0.1002
# Epoch  88  :  Error =  0.1002
# Epoch  89  :  Error =  0.1002
# Epoch  90  :  Error =  0.1002
# Epoch  91  :  Error =  0.1002
# Epoch  92  :  Error =  0.1002
# Epoch  93  :  Error =  0.1002
# Epoch  94  :  Error =  0.1002
# Epoch  95  :  Error =  0.1002
# Epoch  96  :  Error =  0.1001
# Epoch  97  :  Error =  0.1001
# Epoch  98  :  Error =  0.1001
# Epoch  99  :  Error =  0.1001
# Epoch  100  :  Error =  0.1001
# Epoch  101  :  Error =  0.1001
# Epoch  102  :  Error =  0.1001
# Epoch  103  :  Error =  0.1001
# Epoch  104  :  Error =  0.1001
# Epoch  105  :  Error =  0.1001
# Epoch  106  :  Error =  0.1001
# Epoch  107  :  Error =  0.1001
# Epoch  108  :  Error =  0.1001
# Epoch  109  :  Error =  0.1001
# Epoch  110  :  Error =  0.1001
# Epoch  111  :  Error =  0.1001
# Epoch  112  :  Error =  0.1001
# Epoch  113  :  Error =  0.1000
# Epoch  114  :  Error =  0.1000
# Epoch  115  :  Error =  0.1000
# Epoch  116  :  Error =  0.1000
# Epoch  117  :  Error =  0.1000
# Epoch  118  :  Error =  0.1000
# Epoch  119  :  Error =  0.1000
# Epoch  120  :  Error =  0.1000
# Epoch  121  :  Error =  0.1000
# Epoch  122  :  Error =  0.1000
# Epoch  123  :  Error =  0.1000
# Epoch  124  :  Error =  0.1000
# Epoch  44  :  Error =  0.0994
# Epoch  45  :  Error =  0.0994
# Epoch  46  :  Error =  0.0994
# Epoch  47  :  Error =  0.0994
# Epoch  48  :  Error =  0.0994
# Epoch  49  :  Error =  0.0994
# Epoch  50  :  Error =  0.0994
# Epoch  51  :  Error =  0.0994
# Epoch  52  :  Error =  0.0994
# Epoch  53  :  Error =  0.0994
# Epoch  54  :  Error =  0.0994
# Epoch  55  :  Error =  0.0994
# Epoch  56  :  Error =  0.0994
# Epoch  57  :  Error =  0.0994
# Epoch  58  :  Error =  0.0994
# Epoch  59  :  Error =  0.0994
# Epoch  60  :  Error =  0.0994
# Epoch  61  :  Error =  0.0994
# Epoch  62  :  Error =  0.0994
# Epoch  63  :  Error =  0.0994
# Epoch  64  :  Error =  0.0994
# Epoch  65  :  Error =  0.0994
# Epoch  66  :  Error =  0.0994
# Epoch  67  :  Error =  0.0994
# Epoch  68  :  Error =  0.0994
# Epoch  69  :  Error =  0.0994
# Epoch  70  :  Error =  0.0994
# Epoch  71  :  Error =  0.0994
# Epoch  72  :  Error =  0.0994
# Epoch  73  :  Error =  0.0994
# Epoch  74  :  Error =  0.0994
# Epoch  75  :  Error =  0.0994
# Epoch  76  :  Error =  0.0994
# Epoch  77  :  Error =  0.0994
# Epoch  78  :  Error =  0.0994
# Epoch  79  :  Error =  0.0994
# Epoch  80  :  Error =  0.0994
# Epoch  81  :  Error =  0.0994
# Epoch  82  :  Error =  0.0994
# Epoch  83  :  Error =  0.0994
# Epoch  84  :  Error =  0.0994
# Epoch  85  :  Error =  0.0993
# Epoch  86  :  Error =  0.0993
# Epoch  87  :  Error =  0.0993
# Epoch  88  :  Error =  0.0993
# Epoch  89  :  Error =  0.0993
# Epoch  90  :  Error =  0.0993
# Epoch  91  :  Error =  0.0993
# Epoch  92  :  Error =  0.0993
# Epoch  93  :  Error =  0.0993
# Epoch  94  :  Error =  0.0993
# Epoch  95  :  Error =  0.0993
# Epoch  96  :  Error =  0.0993
# Epoch  97  :  Error =  0.0993
# Epoch  98  :  Error =  0.0993
# Epoch  99  :  Error =  0.0993
# Epoch  100  :  Error =  0.0993
# Epoch  101  :  Error =  0.0993
# Epoch  102  :  Error =  0.0993
# Epoch  103  :  Error =  0.0993
# Epoch  104  :  Error =  0.0993
# Epoch  105  :  Error =  0.0993
# Epoch  106  :  Error =  0.0993
# Epoch  107  :  Error =  0.0993
# Epoch  108  :  Error =  0.0993
# Epoch  109  :  Error =  0.0993
# Epoch  110  :  Error =  0.0993
# Epoch  111  :  Error =  0.0993
# Epoch  112  :  Error =  0.0993
# Epoch  113  :  Error =  0.0993
# Epoch  114  :  Error =  0.0993
# Epoch  115  :  Error =  0.0993
# Epoch  116  :  Error =  0.0993
# Epoch  117  :  Error =  0.0993
# Epoch  118  :  Error =  0.0993
# Epoch  119  :  Error =  0.0993
# Epoch  120  :  Error =  0.0993
# Epoch  121  :  Error =  0.0993
# Epoch  122  :  Error =  0.0993
# Epoch  123  :  Error =  0.0993
# Epoch  124  :  Error =  0.0993
# Epoch  125  :  Error =  0.0993
# Epoch  126  :  Error =  0.0993
# Epoch  127  :  Error =  0.0993
# Epoch  128  :  Error =  0.0993
# Epoch  129  :  Error =  0.0993
# Epoch  130  :  Error =  0.0993
# Epoch  131  :  Error =  0.0993
# Epoch  132  :  Error =  0.0992
# Epoch  133  :  Error =  0.0992
# Epoch  134  :  Error =  0.0992
# Epoch  135  :  Error =  0.0992
# Epoch  136  :  Error =  0.0992
# Epoch  137  :  Error =  0.0992
# Epoch  138  :  Error =  0.0992
# Epoch  139  :  Error =  0.0992
# Epoch  140  :  Error =  0.0992
# Epoch  141  :  Error =  0.0992
# Epoch  142  :  Error =  0.0992
# Epoch  143  :  Error =  0.0992
# Epoch  144  :  Error =  0.0992
# Epoch  145  :  Error =  0.0992
# Epoch  146  :  Error =  0.0992
# Epoch  147  :  Error =  0.0992
# Epoch  148  :  Error =  0.0992
# Epoch  149  :  Error =  0.0992
# Epoch  150  :  Error =  0.0992
# Epoch  151  :  Error =  0.0992
# Epoch  152  :  Error =  0.0992
# Epoch  153  :  Error =  0.0992
# Epoch  154  :  Error =  0.0992
# Epoch  155  :  Error =  0.0992
# Epoch  156  :  Error =  0.0992
# Epoch  157  :  Error =  0.0992
# Epoch  158  :  Error =  0.0992
# Epoch  159  :  Error =  0.0992
# Epoch  160  :  Error =  0.0992
# Epoch  161  :  Error =  0.0992
# Epoch  162  :  Error =  0.0992
# Epoch  163  :  Error =  0.0992
# Epoch  164  :  Error =  0.0992
# Epoch  165  :  Error =  0.0992
# Epoch  166  :  Error =  0.0992
# Epoch  167  :  Error =  0.0992
# Epoch  168  :  Error =  0.0992
# Epoch  169  :  Error =  0.0992
# Epoch  170  :  Error =  0.0992
# Epoch  171  :  Error =  0.0992
# Epoch  172  :  Error =  0.0992
# Epoch  173  :  Error =  0.0992
# Epoch  174  :  Error =  0.0992
# Epoch  175  :  Error =  0.0992
# Epoch  176  :  Error =  0.0992
# Epoch  177  :  Error =  0.0992
# Epoch  178  :  Error =  0.0992
# Epoch  179  :  Error =  0.0992
# Epoch  180  :  Error =  0.0992
# Epoch  181  :  Error =  0.0992
# Epoch  182  :  Error =  0.0992
# Epoch  183  :  Error =  0.0992
# Epoch  184  :  Error =  0.0992
# Epoch  185  :  Error =  0.0991
# Epoch  186  :  Error =  0.0991
# Epoch  187  :  Error =  0.0991
# Epoch  188  :  Error =  0.0991
# Epoch  189  :  Error =  0.0991
# Epoch  190  :  Error =  0.0991
# Epoch  191  :  Error =  0.0991
# Epoch  192  :  Error =  0.0991
# Epoch  193  :  Error =  0.0991
# Epoch  194  :  Error =  0.0991
# Epoch  195  :  Error =  0.0991
# Epoch  196  :  Error =  0.0991
# Epoch  197  :  Error =  0.0991
# Epoch  198  :  Error =  0.0991
# Epoch  199  :  Error =  0.0991
# Epoch  200  :  Error =  0.0991
#
#
# Training accuracy is :  0.6891
# Testing accuracy average of all folds is :  0.6905
# Final testing accuracy is :  0.7178
#
#
# Execution time in seconds =  0:01:32.785499
